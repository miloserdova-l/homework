t10 = [[7.608, 7.645, 7.454, 8.277, 8.253, 8.719, 8.805, 8.718, 8.776, 8.599, 8.519, 9.026, 8.441, 9.048, 8.237, 8.434, 8.67, 8.295, 8.912, 8.615],
       [11.452, 12.509, 12.694, 12.697, 12.89, 13.277, 13.38, 13.628, 13.59, 13.599, 14.028, 14.181, 13.676, 13.461, 13.717, 13.633, 14.03, 13.968, 13.503, 13.45],
       [17.221, 18.119, 19.25, 19.408, 19.501, 19.822, 20.368, 20.047, 19.917, 20.475, 20.097, 19.81, 20.238, 19.934, 19.869, 20.39, 20.196, 20.313, 19.869, 19.792],
       [26.022, 26.523, 27.04, 27.445, 27.594, 27.53, 27.435, 27.918, 27.643, 28.186, 27.24, 27.731, 28.164, 27.353, 28.011, 27.249, 27.965, 27.783, 27.383, 27.698],
       [33.695, 34.678, 35.08, 36.267, 35.669, 36.575, 36.694, 35.863, 36.962, 36.887, 37.189, 36.862, 36.765, 36.192, 36.814, 36.522, 36.332, 36.494, 37.251, 36.874],
       [68.155, 69.146, 69.45, 69.674, 69.577, 70.214, 70.528, 70.839, 70.848, 70.744, 71.198, 70.711, 71.328, 71.488, 71.085, 71.914, 70.834, 71.036, 71.174, 71.589],
       [80.192, 82.94, 83.546, 83.51, 83.953, 84.116, 83.921, 83.74, 83.321, 83.698, 83.835, 84.181, 83.516, 83.914, 83.466, 83.811, 84.19, 83.76, 83.46, 83.602],
       [145.619, 148.559, 148.021, 148.623, 148.759, 148.439, 149.276, 149.69, 149.54, 148.914, 149.931, 149.255, 149.124, 149.477, 150.227, 149.413, 149.761, 150.155, 150.264, 150.774]]

y5 = [0] * 8
z5 = [0] * 8
y10 = [0] * 8
z10 = [0] * 8
for i in range(8):
    y5[i] = sum(t5[i]) / len(t5[i])
    t5[i].sort()
    z5[i] = t5[i][len(t5[i]) // 2]
    y10[i] = sum(t10[i]) / len(t10[i])
    t10[i].sort()
    z10[i] = t10[i][len(t10[i]) // 2]

plt.figure(figsize=(10, 10))
plt.plot(x, y5, color='green', marker='o', linewidth=3, markersize=9, label='5 req/sec среднее значение')
plt.plot(x, z5, color='blue', marker='o', linewidth=1, markersize=5, label='5 req/sec медианное значение')
plt.plot(x, y10, color='red', marker='o', linewidth=3, markersize=9, label='10 req/sec среднее значение')
plt.plot(x, z10, color='yellow', marker='o', linewidth=1, markersize=5, label='10 req/sec медианное значение')

plt.legend()

plt.savefig("nonFixedImage.png")

# %% [markdown]
# При 9 запросах в секунду происходит отказ от обслуживания (размер изображения 360x540 пикселей), так как ожидание клиента превышает одну минуту.
